# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sheet_names = pd.ExcelFile("/Users/apple/Downloads/Assingment_Dataset.xlsx").sheet_names
print(sheet_names)
# Out:
# ['Geospatial Data', 'Satellite Details', 'News Reports', 'Historical Incidents']

# %%
satellite_details= pd.read_excel("/Users/apple/Downloads/Assingment_Dataset.xlsx", sheet_name='Satellite Details')

# %%
satellite_details
# Out:
#     Image ID       Date             Location  \
# 0          1 2024-03-01    Border Post Alpha
# 1          2 2024-03-03    Border Post Alpha
# 2          3 2024-03-05    Border Post Alpha
# 3          4 2024-03-07    Border Post Alpha
# 4          5 2024-03-09    Border Post Alpha
# 5          6 2024-03-12    Border Post Bravo
# 6          7 2024-03-14    Border Post Bravo
# 7          8 2024-03-17    Border Post Bravo
# 8          9 2024-03-19    Border Post Bravo
# 9         10 2024-03-22    Border Post Bravo
# 10        11 2024-03-24  Border Post Charlie
# 11        12 2024-03-27  Border Post Charlie
# 12        13 2024-03-29  Border Post Charlie
# 13        14 2024-04-01  Border Post Charlie
# 14        15 2024-04-03  Border Post Charlie
# 15        16 2024-04-05    Border Post Delta
# 16        17 2024-04-07    Border Post Delta
# 17        18 2024-04-10    Border Post Delta
# 18        19 2024-04-12    Border Post Delta
# 19        20 2024-04-15    Border Post Delta
# 20        21 2024-04-17     Border Post Echo
# 21        22 2024-04-19     Border Post Echo
# 22        23 2024-04-22     Border Post Echo
# 23        24 2024-04-24     Border Post Echo
# 24        25 2024-04-27     Border Post Echo
# 25        26 2024-04-29  Border Post Foxtrot
# 26        27 2024-05-02  Border Post Foxtrot
# 27        28 2024-05-04  Border Post Foxtrot
# 28        29 2024-05-07  Border Post Foxtrot
# 29        30 2024-05-09  Border Post Foxtrot
#
#                                        Description
# 0   High-resolution image showing vehicle movement
# 1        Image showing increased military presence
# 2                      Image showing an empty area
# 3                   Image showing troop withdrawal
# 4    Image showing new infrastructure developments
# 5   High-resolution image showing vehicle movement
# 6        Image showing increased military presence
# 7                      Image showing an empty area
# 8                   Image showing troop withdrawal
# 9    Image showing new infrastructure developments
# 10  High-resolution image showing vehicle movement
# 11       Image showing increased military presence
# 12                     Image showing an empty area
# 13                  Image showing troop withdrawal
# 14   Image showing new infrastructure developments
# 15  High-resolution image showing vehicle movement
# 16       Image showing increased military presence
# 17                     Image showing an empty area
# 18                  Image showing troop withdrawal
# 19   Image showing new infrastructure developments
# 20  High-resolution image showing vehicle movement
# 21       Image showing increased military presence
# 22                     Image showing an empty area
# 23                  Image showing troop withdrawal
# 24   Image showing new infrastructure developments
# 25  High-resolution image showing vehicle movement
# 26       Image showing increased military presence
# 27                     Image showing an empty area
# 28                  Image showing troop withdrawal
# 29   Image showing new infrastructure developments

# %%
satellite_details.size
# Out:
# 120

# %%
satellite_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Image ID     30 non-null     int64
#  1   Date         30 non-null     datetime64[ns]
#  2   Location     30 non-null     object
#  3   Description  30 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
satellite_details['Date'] = pd.to_datetime(satellite_details['Date'], format='%d-%m-%Y')
satellite_details
# Out:
#     Image ID       Date             Location  \
# 0          1 2024-03-01    Border Post Alpha
# 1          2 2024-03-03    Border Post Alpha
# 2          3 2024-03-05    Border Post Alpha
# 3          4 2024-03-07    Border Post Alpha
# 4          5 2024-03-09    Border Post Alpha
# 5          6 2024-03-12    Border Post Bravo
# 6          7 2024-03-14    Border Post Bravo
# 7          8 2024-03-17    Border Post Bravo
# 8          9 2024-03-19    Border Post Bravo
# 9         10 2024-03-22    Border Post Bravo
# 10        11 2024-03-24  Border Post Charlie
# 11        12 2024-03-27  Border Post Charlie
# 12        13 2024-03-29  Border Post Charlie
# 13        14 2024-04-01  Border Post Charlie
# 14        15 2024-04-03  Border Post Charlie
# 15        16 2024-04-05    Border Post Delta
# 16        17 2024-04-07    Border Post Delta
# 17        18 2024-04-10    Border Post Delta
# 18        19 2024-04-12    Border Post Delta
# 19        20 2024-04-15    Border Post Delta
# 20        21 2024-04-17     Border Post Echo
# 21        22 2024-04-19     Border Post Echo
# 22        23 2024-04-22     Border Post Echo
# 23        24 2024-04-24     Border Post Echo
# 24        25 2024-04-27     Border Post Echo
# 25        26 2024-04-29  Border Post Foxtrot
# 26        27 2024-05-02  Border Post Foxtrot
# 27        28 2024-05-04  Border Post Foxtrot
# 28        29 2024-05-07  Border Post Foxtrot
# 29        30 2024-05-09  Border Post Foxtrot
#
#                                        Description
# 0   High-resolution image showing vehicle movement
# 1        Image showing increased military presence
# 2                      Image showing an empty area
# 3                   Image showing troop withdrawal
# 4    Image showing new infrastructure developments
# 5   High-resolution image showing vehicle movement
# 6        Image showing increased military presence
# 7                      Image showing an empty area
# 8                   Image showing troop withdrawal
# 9    Image showing new infrastructure developments
# 10  High-resolution image showing vehicle movement
# 11       Image showing increased military presence
# 12                     Image showing an empty area
# 13                  Image showing troop withdrawal
# 14   Image showing new infrastructure developments
# 15  High-resolution image showing vehicle movement
# 16       Image showing increased military presence
# 17                     Image showing an empty area
# 18                  Image showing troop withdrawal
# 19   Image showing new infrastructure developments
# 20  High-resolution image showing vehicle movement
# 21       Image showing increased military presence
# 22                     Image showing an empty area
# 23                  Image showing troop withdrawal
# 24   Image showing new infrastructure developments
# 25  High-resolution image showing vehicle movement
# 26       Image showing increased military presence
# 27                     Image showing an empty area
# 28                  Image showing troop withdrawal
# 29   Image showing new infrastructure developments

# %%
satellite_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Image ID     30 non-null     int64
#  1   Date         30 non-null     datetime64[ns]
#  2   Location     30 non-null     object
#  3   Description  30 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
satellite_details.describe()
# Out:
#         Image ID
# count  30.000000
# mean   15.500000
# std     8.803408
# min     1.000000
# 25%     8.250000
# 50%    15.500000
# 75%    22.750000
# max    30.000000

# %%
satellite_details.isnull().sum()
# Out:
# Image ID       0
# Date           0
# Location       0
# Description    0
# dtype: int64

# %%
grouped_data = satellite_details.groupby('Location')
for name, group in grouped_data:
    print(f"Border Post: {name}")
    print(group)
    print("\n")
# Out:
# Border Post: Border Post Alpha
#    Image ID       Date           Location  \
# 0         1 2024-03-01  Border Post Alpha
# 1         2 2024-03-03  Border Post Alpha
# 2         3 2024-03-05  Border Post Alpha
# 3         4 2024-03-07  Border Post Alpha
# 4         5 2024-03-09  Border Post Alpha
#
#                                       Description
# 0  High-resolution image showing vehicle movement
# 1       Image showing increased military presence
# 2                     Image showing an empty area
# 3                  Image showing troop withdrawal
# 4   Image showing new infrastructure developments
#
#
# Border Post: Border Post Bravo
#    Image ID       Date           Location  \
# 5         6 2024-03-12  Border Post Bravo
# 6         7 2024-03-14  Border Post Bravo
# 7         8 2024-03-17  Border Post Bravo
# 8         9 2024-03-19  Border Post Bravo
# 9        10 2024-03-22  Border Post Bravo
#
#                                       Description
# 5  High-resolution image showing vehicle movement
# 6       Image showing increased military presence
# 7                     Image showing an empty area
# 8                  Image showing troop withdrawal
# 9   Image showing new infrastructure developments
#
#
# Border Post: Border Post Charlie
#     Image ID       Date             Location  \
# 10        11 2024-03-24  Border Post Charlie
# 11        12 2024-03-27  Border Post Charlie
# 12        13 2024-03-29  Border Post Charlie
# 13        14 2024-04-01  Border Post Charlie
# 14        15 2024-04-03  Border Post Charlie
#
#                                        Description
# 10  High-resolution image showing vehicle movement
# 11       Image showing increased military presence
# 12                     Image showing an empty area
# 13                  Image showing troop withdrawal
# 14   Image showing new infrastructure developments
#
#
# Border Post: Border Post Delta
#     Image ID       Date           Location  \
# 15        16 2024-04-05  Border Post Delta
# 16        17 2024-04-07  Border Post Delta
# 17        18 2024-04-10  Border Post Delta
# 18        19 2024-04-12  Border Post Delta
# 19        20 2024-04-15  Border Post Delta
#
#                                        Description
# 15  High-resolution image showing vehicle movement
# 16       Image showing increased military presence
# 17                     Image showing an empty area
# 18                  Image showing troop withdrawal
# 19   Image showing new infrastructure developments
#
#
# Border Post: Border Post Echo
#     Image ID       Date          Location  \
# 20        21 2024-04-17  Border Post Echo
# 21        22 2024-04-19  Border Post Echo
# 22        23 2024-04-22  Border Post Echo
# 23        24 2024-04-24  Border Post Echo
# 24        25 2024-04-27  Border Post Echo
#
#                                        Description
# 20  High-resolution image showing vehicle movement
# 21       Image showing increased military presence
# 22                     Image showing an empty area
# 23                  Image showing troop withdrawal
# 24   Image showing new infrastructure developments
#
#
# Border Post: Border Post Foxtrot
#     Image ID       Date             Location  \
# 25        26 2024-04-29  Border Post Foxtrot
# 26        27 2024-05-02  Border Post Foxtrot
# 27        28 2024-05-04  Border Post Foxtrot
# 28        29 2024-05-07  Border Post Foxtrot
# 29        30 2024-05-09  Border Post Foxtrot
#
#                                        Description
# 25  High-resolution image showing vehicle movement
# 26       Image showing increased military presence
# 27                     Image showing an empty area
# 28                  Image showing troop withdrawal
# 29   Image showing new infrastructure developments

# %%
def analyze_border_post(group):
    # Count the occurrences of each type of description
    description_counts = group['Description'].value_counts()
    return description_counts

# %%
border_post_analysis = grouped_data.apply(analyze_border_post)
border_post_analysis
# Out:
# Description          High-resolution image showing vehicle movement  \
# Location
# Border Post Alpha                                                 1
# Border Post Bravo                                                 1
# Border Post Charlie                                               1
# Border Post Delta                                                 1
# Border Post Echo                                                  1
# Border Post Foxtrot                                               1
#
# Description          Image showing increased military presence  \
# Location
# Border Post Alpha                                            1
# Border Post Bravo                                            1
# Border Post Charlie                                          1
# Border Post Delta                                            1
# Border Post Echo                                             1
# Border Post Foxtrot                                          1
#
# Description          Image showing an empty area  \
# Location
# Border Post Alpha                              1
# Border Post Bravo                              1
# Border Post Charlie                            1
# Border Post Delta                              1
# Border Post Echo                               1
# Border Post Foxtrot                            1
#
# Description          Image showing troop withdrawal  \
# Location
# Border Post Alpha                                 1
# Border Post Bravo                                 1
# Border Post Charlie                               1
# Border Post Delta                                 1
# Border Post Echo                                  1
# Border Post Foxtrot                               1
#
# Description          Image showing new infrastructure developments
# Location
# Border Post Alpha                                                1
# Border Post Bravo                                                1
# Border Post Charlie                                              1
# Border Post Delta                                                1
# Border Post Echo                                                 1
# Border Post Foxtrot                                              1

# %%
plt.figure(figsize=(14, 8))
for location, group in grouped_data:
    plt.plot(group['Date'], group['Description'], marker='o', label=location)
plt.xlabel('Date')
plt.ylabel('Description')
plt.title('Changes in Border Post Descriptions Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
activity_counts = satellite_details['Description'].value_counts()
activity_counts.plot(kind='barh', figsize=(6, 4))
plt.title('Frequency of Activities by Description')
plt.xlabel('Activity Description')
plt.ylabel('Count')
plt.show()

# %%
satellite_details.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
satellite_details.groupby('Location').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
